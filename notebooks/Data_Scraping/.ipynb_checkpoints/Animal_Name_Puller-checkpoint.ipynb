# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3056/3898778119.py in <module>
#       1 # Dependencies
# ----> 2 from splinter import Browser
#       3 from bs4 import BeautifulSoup
#       4 import requests
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'splinter'

# %%
# Use Chrome to scrape the following url
executable_path = {'executable_path': '../chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Url for species directory in www.worldwildlife.org
url= 'https://www.worldwildlife.org/species/directory'

# Navigate to url
browser.visit(url)

# %%
# List to store common and scientific names for each row of table
cols = []

# Loop through two pages
for x in range(2):
    # Parse HTML with BeautifulSoup
    soup = BeautifulSoup(browser.html, 'html.parser')
    
    # Find the table
    table = soup.find('table', class_='lead')
    
    # Retrieve all rows from the table
    rows = table.tbody.find_all('tr')
    
    # Loop through each row to scrape column data of interest and append to "cols" list
    for row in rows:
        col_queries = row.find_all('td')
        col = [col_queries[i].text.strip() for i in range(2)]
        cols.append(col)
    
    try:
        # Navigate to the second page by "click" the "2" button on website
        browser.click_link_by_partial_text('2')
    
    except:
        print('Scraping Complete')
        
# Check the length of "cols"        
len(cols)
# Out:
# Scraping Complete
# 100

# %%
# Setup a Pandas DataFrame to store column data from "cols"
name_df = pd.DataFrame(columns=['Common_Name', 'Sci_Name'])

name_df['Common_Name'] = [cols[i][0] for i in range(len(cols))]
name_df['Sci_Name'] = [cols[i][1] for i in range(len(cols))]

# Preview "name_df"
name_df.head()
# Out:
#             Common_Name                          Sci_Name
# 0      African Elephant                Loxodonta africana
# 1      African Wild Dog                     Lycaon pictus
# 2         Albacore Tuna                  Thunnus alalunga
# 3  Amazon River Dolphin  Scientific Name Inia geoffrensis
# 4          Amur Leopard        Panthera pardus orientalis

# %%
# Close the browser
browser.quit()

# %%
# Read animal species data
animal_df = pd.read_csv("../../data/animal_list_original.csv", encoding="UTF-8")

# Preview "animal_df"
animal_df.head()
# Out:
#             Common_Name Other_Name  \
# 0      African Elephant        NaN
# 1      African Wild Dog        NaN
# 2         Albacore Tuna        NaN
# 3  Amazon River Dolphin        NaN
# 4          Amur Leopard        NaN
#
#                                             Full_url
# 0  https://www.iucnredlist.org/species/12392/3339343
# 1  https://www.iucnredlist.org/species/12436/1671...
# 2  https://www.iucnredlist.org/species/21856/9325450
# 3  https://www.iucnredlist.org/species/10831/5035...
# 4  https://www.iucnredlist.org/species/15954/1024...

# %%
# Delete "Full_url" column from "animal_df"
del animal_df['Full_url']

# Preview "animal_df"
animal_df.head()
# Out:
#             Common_Name Other_Name
# 0      African Elephant        NaN
# 1      African Wild Dog        NaN
# 2         Albacore Tuna        NaN
# 3  Amazon River Dolphin        NaN
# 4          Amur Leopard        NaN

# %%
# Merge "animal_df" with "name_df" on "Common_Name" column and save results as "animal_name_df"
animal_name_df = animal_df.merge(name_df, on='Common_Name', how='left')

# Check length of "animal_name_df"
len(animal_name_df)
# Out:
# 69

# %%
# Set maximum displayed rows to be 70 to double check "Scientific Names"
pd.options.display.max_rows = 70

# View "animal_name_df"
animal_name_df
# Out:
#                     Common_Name                      Other_Name  \
# 0              African Elephant                             NaN
# 1              African Wild Dog                             NaN
# 2                 Albacore Tuna                             NaN
# 3          Amazon River Dolphin                             NaN
# 4                  Amur Leopard                             NaN
# 5                    Arctic Fox                             NaN
# 6                   Arctic Wolf                       Grey Wolf
# 7                Asian Elephant                             NaN
# 8                        Beluga                    Beluga Whale
# 9                   Bigeye Tuna                             NaN
# 10                  Black Rhino                             NaN
# 11          Black Spider Monkey            Guiana Spider Monkey
# 12          Black-footed Ferret                             NaN
# 13                   Blue Whale                             NaN
# 14                 Bluefin Tuna                             NaN
# 15                       Bonobo                             NaN
# 16            Bornean Orangutan                             NaN
# 17                Bowhead Whale                             NaN
# 18                   Brown Bear                             NaN
# 19                   Chimpanzee                             NaN
# 20    Common Bottlenose Dolphin                             NaN
# 21                       Dugong                             NaN
# 22      Eastern Lowland Gorilla                Eastern Gorilla
# 23                    Fin Whale                             NaN
# 24            Galapagos Penguin                             NaN
# 25         Ganges River Dolphin       South Asian River Dolphin
# 26                  Giant Panda                             NaN
# 27                   Gray Whale                             NaN
# 28            Great White Shark                             NaN
# 29     Greater One-Horned Rhino               Indian Rhinoceros
# 30          Greater Sage-Grouse                     Sage Grouse
# 31                 Green Turtle                             NaN
# 32             Hawksbill Turtle                             NaN
# 33             Hector's Dolphin                             NaN
# 34                 Hippopotamus                             NaN
# 35              Humphead Wrasse                             NaN
# 36            Irrawaddy Dolphin                             NaN
# 37                       Jaguar                             NaN
# 38                  Javan Rhino                             NaN
# 39           Leatherback Turtle                             NaN
# 40            Loggerhead Turtle                             NaN
# 41                        Macaw                             NaN
# 42                Marine Iguana        Fernandina Marine Iguana
# 43              Mountain Plover                             NaN
# 44                      Narwhal                             NaN
# 45   North Atlantic Right Whale                             NaN
# 46          Olive Ridley Turtle                             NaN
# 47                 Plains Bison                  American Bison
# 48             Poison Dart Frog                             NaN
# 49                   Polar Bear                             NaN
# 50                    Pronghorn                             NaN
# 51                    Red Panda                             NaN
# 52                        Saola                             NaN
# 53                    Sea Lions                             NaN
# 54                    Sei Whale                             NaN
# 55                Skipjack Tuna                             NaN
# 56                 Snow Leopard                             NaN
# 57  Southern rockhopper penguin                             NaN
# 58           Sumatran Orangutan                             NaN
# 59               Sumatran Rhino                             NaN
# 60                    Swift Fox                             NaN
# 61                        Tiger                             NaN
# 62                Tree Kangaroo                             NaN
# 63                      Vaquita                             NaN
# 64      Western Lowland Gorilla                 Western Gorilla
# 65                  Whale Shark                             NaN
# 66                  White Rhino                             NaN
# 67     Yangtze Finless Porpoise  Narrow-ridged Finless Porpoise
# 68               Yellowfin Tuna                             NaN
#
#                                             Sci_Name
# 0                                 Loxodonta africana
# 1                                      Lycaon pictus
# 2                                   Thunnus alalunga
# 3                   Scientific Name Inia geoffrensis
# 4                         Panthera pardus orientalis
# 5                                     Vulpes lagopus
# 6                                 Canis lupus arctos
# 7                            Elephas maximus indicus
# 8                              Delphinapterus leucas
# 9                                     Thunnus obesus
# 10                                  Diceros bicornis
# 11                                   Ateles paniscus
# 12                                  Mustela nigripes
# 13                             Balaenoptera musculus
# 14                                   Thunnus Thynnus
# 15                                      Pan paniscus
# 16                                    Pongo pygmaeus
# 17                                Balaena mysticetus
# 18                                      Ursus arctos
# 19                                   Pan troglodytes
# 20                                Tursiops truncates
# 21                                      Dugong dugon
# 22                          Gorilla beringei graueri
# 23                             Balaenoptera physalus
# 24                                               NaN
# 25                    Platanista gangetica gangetica
# 26                            Ailuropoda melanoleuca
# 27                             Eschrichtius robustus
# 28                            Carcharodon carcharias
# 29                              Rhinoceros unicornis
# 30                         Centrocercus urophasianus
# 31                                    Chelonia mydas
# 32                            Eretmochelys imbricata
# 33                           Cephalorhynchus hectori
# 34                            Hippopotamus amphibius
# 35                               Cheilinus undulatus
# 36                             Orcaella brevirostris
# 37                                     Panthera onca
# 38                              Rhinoceros sondaicus
# 39                              Dermochelys coriacea
# 40                                   Caretta caretta
# 41                                      Ara ararauna
# 42                           Amblyrhynchus cristatus
# 43                               Charadrius montanus
# 44                                 Monodon monoceros
# 45                               Eubalaena glacialis
# 46                             Lepidochelys olivacea
# 47                                 Bison bison bison
# 48                               Dendrobates species
# 49                                   Ursus maritimus
# 50                             Antilocarpa americana
# 51                                   Ailurus fulgens
# 52                           Pseudoryx nghetinhensis
# 53                               Zalophus wollebaeki
# 54                             Balaenoptera borealis
# 55                                Katsuwonus pelamis
# 56                                    Panthera uncia
# 57                               Eudyptes chrysocome
# 58                                      Pongo abelii
# 59                          Dicerorhinus sumatrensis
# 60                                      Vulpes velox
# 61                                   Panthera tigris
# 62                                   Dendrolagus sp.
# 63                                    Phocoena sinus
# 64                           Gorilla gorilla gorilla
# 65                                   Rhincodon typus
# 66                               Ceratotherium simum
# 67  Neophocaena asiaeorientalis ssp. asiaeorientalis
# 68                                 Thunnus albacares

# %%
# Make changes in "Sci_Name" column wherever are needed
animal_name_df['Sci_Name'][3] = 'Inia geoffrensis'
animal_name_df['Sci_Name'][4] = 'Panthera pardus'
animal_name_df['Sci_Name'][6] = 'Canis lupus'
animal_name_df['Sci_Name'][7] = 'Elephas maximus'
animal_name_df['Sci_Name'][22] = 'Gorilla beringei'
animal_name_df['Sci_Name'][24] = 'Spheniscus mendiculus'
animal_name_df['Sci_Name'][25] = 'Platanista gangetica'
animal_name_df['Sci_Name'][47] = 'Bison bison'
animal_name_df['Sci_Name'][48] = 'Dendrobates leucomelas'
animal_name_df['Sci_Name'][50] = 'Antilocapra americana'
animal_name_df['Sci_Name'][67] = 'Neophocaena asiaeorientalis'

# View "animal_name_df"
animal_name_df
# Out:
#                     Common_Name                      Other_Name  \
# 0              African Elephant                             NaN
# 1              African Wild Dog                             NaN
# 2                 Albacore Tuna                             NaN
# 3          Amazon River Dolphin                             NaN
# 4                  Amur Leopard                             NaN
# 5                    Arctic Fox                             NaN
# 6                   Arctic Wolf                       Grey Wolf
# 7                Asian Elephant                             NaN
# 8                        Beluga                    Beluga Whale
# 9                   Bigeye Tuna                             NaN
# 10                  Black Rhino                             NaN
# 11          Black Spider Monkey            Guiana Spider Monkey
# 12          Black-footed Ferret                             NaN
# 13                   Blue Whale                             NaN
# 14                 Bluefin Tuna                             NaN
# 15                       Bonobo                             NaN
# 16            Bornean Orangutan                             NaN
# 17                Bowhead Whale                             NaN
# 18                   Brown Bear                             NaN
# 19                   Chimpanzee                             NaN
# 20    Common Bottlenose Dolphin                             NaN
# 21                       Dugong                             NaN
# 22      Eastern Lowland Gorilla                Eastern Gorilla
# 23                    Fin Whale                             NaN
# 24            Galapagos Penguin                             NaN
# 25         Ganges River Dolphin       South Asian River Dolphin
# 26                  Giant Panda                             NaN
# 27                   Gray Whale                             NaN
# 28            Great White Shark                             NaN
# 29     Greater One-Horned Rhino               Indian Rhinoceros
# 30          Greater Sage-Grouse                     Sage Grouse
# 31                 Green Turtle                             NaN
# 32             Hawksbill Turtle                             NaN
# 33             Hector's Dolphin                             NaN
# 34                 Hippopotamus                             NaN
# 35              Humphead Wrasse                             NaN
# 36            Irrawaddy Dolphin                             NaN
# 37                       Jaguar                             NaN
# 38                  Javan Rhino                             NaN
# 39           Leatherback Turtle                             NaN
# 40            Loggerhead Turtle                             NaN
# 41                        Macaw                             NaN
# 42                Marine Iguana        Fernandina Marine Iguana
# 43              Mountain Plover                             NaN
# 44                      Narwhal                             NaN
# 45   North Atlantic Right Whale                             NaN
# 46          Olive Ridley Turtle                             NaN
# 47                 Plains Bison                  American Bison
# 48             Poison Dart Frog                             NaN
# 49                   Polar Bear                             NaN
# 50                    Pronghorn                             NaN
# 51                    Red Panda                             NaN
# 52                        Saola                             NaN
# 53                    Sea Lions                             NaN
# 54                    Sei Whale                             NaN
# 55                Skipjack Tuna                             NaN
# 56                 Snow Leopard                             NaN
# 57  Southern rockhopper penguin                             NaN
# 58           Sumatran Orangutan                             NaN
# 59               Sumatran Rhino                             NaN
# 60                    Swift Fox                             NaN
# 61                        Tiger                             NaN
# 62                Tree Kangaroo                             NaN
# 63                      Vaquita                             NaN
# 64      Western Lowland Gorilla                 Western Gorilla
# 65                  Whale Shark                             NaN
# 66                  White Rhino                             NaN
# 67     Yangtze Finless Porpoise  Narrow-ridged Finless Porpoise
# 68               Yellowfin Tuna                             NaN
#
#                        Sci_Name
# 0            Loxodonta africana
# 1                 Lycaon pictus
# 2              Thunnus alalunga
# 3              Inia geoffrensis
# 4               Panthera pardus
# 5                Vulpes lagopus
# 6                   Canis lupus
# 7               Elephas maximus
# 8         Delphinapterus leucas
# 9                Thunnus obesus
# 10             Diceros bicornis
# 11              Ateles paniscus
# 12             Mustela nigripes
# 13        Balaenoptera musculus
# 14              Thunnus Thynnus
# 15                 Pan paniscus
# 16               Pongo pygmaeus
# 17           Balaena mysticetus
# 18                 Ursus arctos
# 19              Pan troglodytes
# 20           Tursiops truncates
# 21                 Dugong dugon
# 22             Gorilla beringei
# 23        Balaenoptera physalus
# 24        Spheniscus mendiculus
# 25         Platanista gangetica
# 26       Ailuropoda melanoleuca
# 27        Eschrichtius robustus
# 28       Carcharodon carcharias
# 29         Rhinoceros unicornis
# 30    Centrocercus urophasianus
# 31               Chelonia mydas
# 32       Eretmochelys imbricata
# 33      Cephalorhynchus hectori
# 34       Hippopotamus amphibius
# 35          Cheilinus undulatus
# 36        Orcaella brevirostris
# 37                Panthera onca
# 38         Rhinoceros sondaicus
# 39         Dermochelys coriacea
# 40              Caretta caretta
# 41                 Ara ararauna
# 42      Amblyrhynchus cristatus
# 43          Charadrius montanus
# 44            Monodon monoceros
# 45          Eubalaena glacialis
# 46        Lepidochelys olivacea
# 47                  Bison bison
# 48       Dendrobates leucomelas
# 49              Ursus maritimus
# 50        Antilocapra americana
# 51              Ailurus fulgens
# 52      Pseudoryx nghetinhensis
# 53          Zalophus wollebaeki
# 54        Balaenoptera borealis
# 55           Katsuwonus pelamis
# 56               Panthera uncia
# 57          Eudyptes chrysocome
# 58                 Pongo abelii
# 59     Dicerorhinus sumatrensis
# 60                 Vulpes velox
# 61              Panthera tigris
# 62              Dendrolagus sp.
# 63               Phocoena sinus
# 64      Gorilla gorilla gorilla
# 65              Rhincodon typus
# 66          Ceratotherium simum
# 67  Neophocaena asiaeorientalis
# 68            Thunnus albacares

# %%
# Save df as csv file
animal_name_df.to_csv("../../data/animal_names.csv", index=False, header=True)
